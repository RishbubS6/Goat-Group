# %% [markdown]
# ---
# permalink: /github/pages/intro
# title: GitHub Pages Intro
# description: A key to learning GitHub Pages.
# toc: true
# ---

# %%
print("Why did the programmer quit his job? Because he didn't get arrays!")

# %%
print("Why do programmers prefer dark mode? Because the light attracts bugs!")

# %%
print("What computer sings the best? A Dell!)
